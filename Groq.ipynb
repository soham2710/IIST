# %% [markdown]
# <a href="https://colab.research.google.com/github/soham2710/IIST/blob/main/Groq.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install langchain langchain-groq
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.5/137.5 kB 3.0 MB/s eta 0:00:00
# ...

# %%
import os
from langchain_groq import ChatGroq

# 🔑 Set your Groq API key
os.environ["GROQ_API_KEY"] = "your-api-key-here"

# 🤖 Initialize model
llm = ChatGroq(
    model="llama3-8b-8192",   # fast + free model
    temperature=0.7
)

# 🔁 Simple text generation loop
while True:
    user_input = input("\nYou: ")

    if user_input.lower() in ["exit", "quit"]:
        print("Goodbye!")
        break

    response = llm.invoke(user_input)

    print("\nAI:", response.content)
